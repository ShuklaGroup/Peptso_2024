# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import pyemma
import glob
import pickle

# %%
msm_object = pickle.load(open("MSM-holo-PepTSo-14dist-4tics-500cls-py.pkl", 'rb'))
dtrajs = pickle.load(open("holo-PepTSo-14dist-4tics-500cls-py.pkl",'rb'))

# %%
tpt = pyemma.msm.tpt(msm_object, [446], [482])
paths, capacities = tpt.pathways(fraction=1.0, maxiter=10)
# Out:
# /home/nicole/miniconda3/envs/pyemma/lib/python3.8/site-packages/deeptime/markov/tools/flux/pathways.py:294: RuntimeWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", RuntimeWarning)

# %%
paths[0]
# Out:
# array([446, 116, 443, 244, 432, 316, 201, 358, 482], dtype=int32)

# %%
for i in range(len(paths)):
    print(i, capacities[i]/np.sum(capacities)*100)
# Out:
# 0 12.696518335346571
# 1 11.368071576430532
# 2 9.749787789026602
# 3 8.478182830263275
# 4 8.453931796122113
# 5 8.372475204969938
# 6 8.354212010691487
# 7 8.262505037424319
# 8 8.231179864423313
# 9 8.154528880564948
# 10 7.8786066747369095
